# %%
import numpy as np
import json
import pandas as pd

# %%
def make_dict_from_jsonl(file_path):
    log_list = []
    with open(file_path) as in_file:
        for line in in_file:
            log_list.append(json.loads(line))
    
    out_dict = {key:[] for key in log_list[0].keys()}
    for log_item in log_list:
        for key, value in log_item.items():
            out_dict[key].append(value)
    return out_dict

# %%
# log_file_path = './data_and_plots/actor_loss_10/reward_logs.jsonl'
# log_file_path = './data_and_plots/actor_loss_5/reward_logs.jsonl'
# log_file_path = './data_and_plots/rl3/reward_logs.jsonl'
log_file_path = './data_and_plots/rl10/reward_logs.jsonl'

# %%
log_dict = make_dict_from_jsonl(log_file_path)

# %%
log_dict.keys()
# Out:
# dict_keys(['mean_classification_reward', 'sum_cumulative_rewards', 'mean_classification_accuracy', 'avg_read_fraction', 'total_loss', 'actor_loss', 'critic_loss', 'entropy_loss', 'classification_loss'])

# %%
len(log_dict["mean_classification_accuracy"])
# Out:
# 10809

# %%
reward_df = pd.DataFrame(data=log_dict)

# %%
reward_df.head()
# Out:
#    mean_classification_reward  sum_cumulative_rewards  \
# 0                    0.886307              184.606308
# 1                    0.550203              101.394897
# 2                    0.731651              147.939133
# 3                    0.590839              113.334038
# 4                    0.630064              124.131119
#
#    mean_classification_accuracy  avg_read_fraction  total_loss  actor_loss  \
# 0                          0.87           0.532985   83.026787   82.385857
# 1                          0.55           0.508539    5.348272    4.818886
# 2                          0.72           0.463436   15.333009   14.865817
# 3                          0.59           0.421846  -10.923723  -11.443774
# 4                          0.63           0.382477    7.163160    6.689730
#
#    critic_loss  entropy_loss  classification_loss
# 0     0.503995      0.695862             0.433236
# 1     0.293134      0.695274             0.764331
# 2     0.286658      0.700777             0.578420
# 3     0.296049      0.712809             0.722914
# 4     0.261191      0.727748             0.683202

# %%
reward_df.describe()
# Out:
#        mean_classification_reward  sum_cumulative_rewards  \
# count                10809.000000            10809.000000
# mean                     0.847853              183.160997
# std                      0.044877               11.460144
# min                      0.520013               98.448029
# 25%                      0.824943              177.422882
# 50%                      0.852569              184.419037
# 75%                      0.878195              190.850037
# max                      0.966209              213.540588
#
#        mean_classification_accuracy  avg_read_fraction    total_loss  \
# count                  10809.000000       10809.000000  10809.000000
# mean                       0.831704           0.177287      0.019973
# std                        0.046476           0.088737      2.630903
# min                        0.520000           0.037614    -17.546730
# 25%                        0.810000           0.113326     -1.173848
# 50%                        0.840000           0.147922      0.121291
# 75%                        0.860000           0.216847      1.296350
# max                        0.960000           0.532985     83.026787
#
#          actor_loss   critic_loss  entropy_loss  classification_loss
# count  10809.000000  10809.000000  10809.000000         10809.000000
# mean      -0.254540      0.117580      1.447278             0.474866
# std        2.650819      0.031242      0.340780             0.043170
# min      -18.083282      0.039892      0.695274             0.354915
# 25%       -1.461059      0.096930      1.246724             0.446266
# 50%       -0.150497      0.113745      1.513246             0.470346
# 75%        1.043765      0.132314      1.671113             0.497068
# max       82.385857      0.503995      2.694845             0.793303

# %%
if "sum_cumulative_rewards" in reward_df:
    reward_df.plot(y="sum_cumulative_rewards")

# %%
reward_df.plot(y="mean_classification_reward")

# %%
reward_df.plot(y="mean_classification_accuracy")

# %%
reward_df.plot(y="avg_read_fraction")

# %%
reward_df.plot(y="actor_loss")

# %%
reward_df.plot(y="critic_loss")

# %%
reward_df.plot(y="entropy_loss")

# %%
reward_df.plot(y="classification_loss")
