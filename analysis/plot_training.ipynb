# %%
import numpy as np
import json
import pandas as pd

# %%
def make_dict_from_jsonl(file_path):
    log_list = []
    with open(file_path) as in_file:
        for line in in_file:
            log_list.append(json.loads(line))
    
    out_dict = {key:[] for key in log_list[0].keys()}
    for log_item in log_list:
        for key, value in log_item.items():
            out_dict[key].append(value)
    return out_dict

# %%
# log_file_path = './data_and_plots/actor_loss_10/reward_logs.jsonl'
log_file_path = './data_and_plots/actor_loss_5/reward_logs.jsonl'

# %%
log_dict = make_dict_from_jsonl(log_file_path)

# %%
log_dict.keys()
# Out:
# dict_keys(['mean_classification_accuracy', 'avg_read_fraction', 'actor_loss', 'critic_loss', 'entropy_loss', 'classification_loss'])

# %%
len(log_dict["mean_classification_accuracy"])
# Out:
# 5511

# %%
reward_df = pd.DataFrame(data=log_dict)

# %%
reward_df.head()
# Out:
#    mean_classification_accuracy  avg_read_fraction  actor_loss  critic_loss  \
# 0                          0.78           0.455425  118.842911     0.990008
# 1                          0.77           0.450222  117.984619     0.932641
# 2                          0.82           0.451689  121.980026     0.970360
# 3                          0.82           0.452303  118.065224     0.949242
# 4                          0.87           0.455789  118.713936     0.965383
#
#    entropy_loss  classification_loss
# 0      0.688212             0.498420
# 1      0.688309             0.535063
# 2      0.687667             0.476917
# 3      0.687307             0.457340
# 4      0.687180             0.439425

# %%
reward_df.describe()
# Out:
#        mean_classification_accuracy  avg_read_fraction   actor_loss  \
# count                   5511.000000        5511.000000  5511.000000
# mean                       0.866050           0.737606     2.145876
# std                        0.046972           0.160787    11.333554
# min                        0.580000           0.407016   -14.836088
# 25%                        0.840000           0.591195    -1.214168
# 50%                        0.870000           0.764176     0.567910
# 75%                        0.900000           0.880261     2.516402
# max                        0.980000           0.992022   126.310661
#
#        critic_loss  entropy_loss  classification_loss
# count  5511.000000   5511.000000          5511.000000
# mean      0.107399      0.332367             0.442975
# std       0.063697      0.168675             0.044036
# min       0.028989      0.030307             0.339195
# 25%       0.079036      0.209866             0.413494
# 50%       0.097163      0.306682             0.436173
# 75%       0.120030      0.414170             0.464394
# max       0.990008      0.688309             0.710635

# %%
reward_df.plot(y="mean_classification_accuracy")

# %%
reward_df.plot(y="avg_read_fraction")

# %%
reward_df.plot(y="actor_loss")

# %%
reward_df.plot(y="critic_loss")

# %%
reward_df.plot(y="entropy_loss")

# %%
reward_df.plot(y="classification_loss")
