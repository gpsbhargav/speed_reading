# %%
import numpy as np
import json
import pandas as pd

# %%
def make_dict_from_jsonl(file_path):
    log_list = []
    with open(file_path) as in_file:
        for line in in_file:
            log_list.append(json.loads(line))
    
    out_dict = {key:[] for key in log_list[0].keys()}
    for log_item in log_list:
        for key, value in log_item.items():
            out_dict[key].append(value)
    return out_dict

# %%
# log_file_path = './data_and_plots/actor_loss_10/reward_logs.jsonl'
# log_file_path = './data_and_plots/actor_loss_5/reward_logs.jsonl'
log_file_path = './data_and_plots/rl3/reward_logs.jsonl'

# %%
log_dict = make_dict_from_jsonl(log_file_path)

# %%
log_dict.keys()
# Out:
# dict_keys(['mean_classification_reward', 'mean_classification_accuracy', 'avg_read_fraction', 'actor_loss', 'critic_loss', 'entropy_loss', 'classification_loss'])

# %%
len(log_dict["mean_classification_accuracy"])
# Out:
# 14989

# %%
reward_df = pd.DataFrame(data=log_dict)

# %%
reward_df.head()
# Out:
#    mean_classification_reward  mean_classification_accuracy  \
# 0                    0.860051                          0.84
# 1                    0.761710                          0.73
# 2                    0.750892                          0.69
# 3                    0.826847                          0.81
# 4                    0.771802                          0.74
#
#    avg_read_fraction  actor_loss  critic_loss  entropy_loss  \
# 0           0.532392   78.181404     0.440939      0.690546
# 1           0.564717   32.974777     0.274249      0.683793
# 2           0.552184   27.222160     0.249599      0.685007
# 3           0.567975   22.534372     0.214206      0.682569
# 4           0.557633    0.539898     0.218892      0.684767
#
#    classification_loss
# 0             0.460986
# 1             0.558530
# 2             0.564976
# 3             0.507880
# 4             0.549470

# %%
reward_df.describe()
# Out:
#        mean_classification_reward  mean_classification_accuracy  \
# count                14989.000000                  14989.000000
# mean                     0.847746                      0.828859
# std                      0.038294                      0.041343
# min                      0.653884                      0.630000
# 25%                      0.823873                      0.800000
# 50%                      0.850055                      0.830000
# 75%                      0.874624                      0.860000
# max                      0.970291                      0.970000
#
#        avg_read_fraction    actor_loss   critic_loss  entropy_loss  \
# count       14989.000000  14989.000000  14989.000000  14989.000000
# mean            0.111555     -0.117907      0.116237      0.227148
# std             0.097315      1.918518      0.025054      0.142486
# min             0.029925    -17.087437      0.044374      0.081393
# 25%             0.059869     -0.477662      0.098914      0.132746
# 50%             0.077957     -0.044314      0.114183      0.178298
# 75%             0.108785      0.355654      0.131526      0.248856
# max             0.665605     78.181404      0.440939      0.690546
#
#        classification_loss
# count         14989.000000
# mean              0.476672
# std               0.036835
# min               0.359577
# 25%               0.450936
# 50%               0.474518
# 75%               0.499961
# max               0.652096

# %%
reward_df.plot(y="mean_classification_reward")

# %%
reward_df.plot(y="mean_classification_accuracy")

# %%
reward_df.plot(y="avg_read_fraction")

# %%
reward_df.plot(y="actor_loss")

# %%
reward_df.plot(y="critic_loss")

# %%
reward_df.plot(y="entropy_loss")

# %%
reward_df.plot(y="classification_loss")
